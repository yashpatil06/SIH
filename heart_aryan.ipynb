# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.dropna()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.fillna(0)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.fillna(method='backfill')
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df1=df[["age","sex","slope"]].loc[:15]

# %%
df2=df[["age","sex","slope"]].loc[16:30]

# %%
df3=df[["age","sex","slope"]].loc[31:45]

# %%
merge=pd.concat([df1,df2,df3])

# %%
merge
# Out:
#     age  sex  slope
# 0    52    1      2
# 1    53    1      0
# 2    70    1      0
# 3    61    1      2
# 4    62    0      1
# 5    58    0      1
# 6    58    1      0
# 7    55    1      1
# 8    46    1      2
# 9    54    1      1
# 10   71    0      1
# 11   43    0      1
# 12   34    0      2
# 13   51    1      1
# 14   52    1      1
# 15   34    0      2
# 16   51    0      2
# 17   54    1      1
# 18   50    0      2
# 19   58    1      2
# 20   60    1      1
# 21   67    0      2
# 22   45    1      1
# 23   63    0      2
# 24   42    0      1
# 25   61    0      1
# 26   44    1      2
# 27   58    0      2
# 28   56    1      1
# 29   55    0      1
# 30   44    1      0
# 31   50    0      2
# 32   57    1      1
# 33   70    1      1
# 34   50    1      2
# 35   46    1      1
# 36   51    1      2
# 37   59    1      2
# 38   64    1      1
# 39   57    1      1
# 40   65    0      2
# 41   54    1      1
# 42   61    0      2
# 43   46    1      2
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df4=pd.DataFrame(df)

# %%
scaler=MinMaxScaler()

# %%
scaled=scaler.fit_transform(df4)

# %%
scaled_df=pd.DataFrame(scaled,columns=df.columns)

# %%
scaled_df
# Out:
#            age  sex        cp  trestbps      chol  fbs  restecg   thalach  \
# 0     0.479167  1.0  0.000000  0.292453  0.196347  0.0      0.5  0.740458
# 1     0.500000  1.0  0.000000  0.433962  0.175799  1.0      0.0  0.641221
# 2     0.854167  1.0  0.000000  0.481132  0.109589  0.0      0.5  0.412214
# 3     0.666667  1.0  0.000000  0.509434  0.175799  0.0      0.5  0.687023
# 4     0.687500  0.0  0.000000  0.415094  0.383562  1.0      0.5  0.267176
# ...        ...  ...       ...       ...       ...  ...      ...       ...
# 1020  0.625000  1.0  0.333333  0.433962  0.216895  0.0      0.5  0.709924
# 1021  0.645833  1.0  0.000000  0.292453  0.301370  0.0      0.0  0.534351
# 1022  0.375000  1.0  0.000000  0.150943  0.340183  0.0      0.0  0.358779
# 1023  0.437500  0.0  0.000000  0.150943  0.292237  0.0      0.0  0.671756
# 1024  0.520833  1.0  0.000000  0.245283  0.141553  0.0      0.5  0.320611
#
#       exang   oldpeak  slope    ca      thal  target
# ...

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.model_selection import train_test_split as tts

# %%
test,train = tts(df)

# %%
len(test)
# Out:
# 768

# %%
from sklearn.linear_model import LinearRegression as lr

# %%
X = df["age"].values

# %%
X=X.reshape(-1,1)

# %%
Y = df["chol"].values

# %%
model = lr()

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict([[50]])
# Out:
# array([240.45690966])

# %%
plt.scatter(X,Y)

# %%
plt.figure(figsize = (12,6))

# %%
sns.boxplot(data = df[["age","chol","thalach"]])
# Out:
# <AxesSubplot:>

# %%
plt.hist(df["age"], bins=15)
# Out:
# (array([  4.,  21.,  18.,  57.,  88.,  89.,  77., 122., 126., 151., 134.,
#          83.,  35.,  11.,   9.]),
#  array([29. , 32.2, 35.4, 38.6, 41.8, 45. , 48.2, 51.4, 54.6, 57.8, 61. ,
#         64.2, 67.4, 70.6, 73.8, 77. ]),
#  <BarContainer object of 15 artists>)

# %%
plt.plot(df["age"],df["chol"])

# %%
plt.plot(df["age"],df["chol"])
plt.plot(df["age"],df["thalach"], color = "red")
